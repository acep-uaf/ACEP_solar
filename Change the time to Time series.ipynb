# %% [markdown]
# ### This notebook try to figure out a way to get the time series that can be sorted by python

# %%
import pandas as pd
import numpy as np
import datetime

# %%
nortech = pd.read_excel('Cleaned_data/nortech_6.6kw_tracking_cleaned.xlsx')
nortech = nortech.fillna("")
uaf = pd.read_excel('Cleaned_data/uaf_fairbanks_cleaned.xlsx')
uaf = uaf.fillna("")

# %%
# for i in range(len(nortech.index)):
#     if nortech['Month'][i] == 'November':
#           nortech['Month'][i] =nortech['Month'][i].replace('November','1')
#           print(nortech['Month'][i])

# %%
# get a column ['Date'],which is in the format of 'Year_month'
def change_month(dataframe):
    Month_change = {'November':11,'December':12,'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10}
    dataframe['Month'] = dataframe['Month'].map(Month_change)
    return(dataframe)


def create_date(dataframe):
    dataframe['Date'] = ""
    for i in range(len(dataframe)):
        dataframe['Date'][i] = str(dataframe['Year'][i]) + '-' + str(dataframe['Month'][i])
    dataframe.drop(['Year','Month'],axis = 1,inplace = True)
    order = ['Date','Energy','DC Capacity','Location']
    dataframe_new = dataframe[order]
    return(dataframe_new)

# %%
def add_time_col(dataframe):
    change_month(dataframe)
    create_date(dataframe)
    return(dataframe_new)

# %%
def add_time_col(dataframe):
    Month_change = {'November':11,'December':12,'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10}
    dataframe['Month'] = dataframe['Month'].map(Month_change)
    dataframe['Date'] = ""
    for i in range(len(dataframe)):
        dataframe['Date'][i] = str(dataframe['Year'][i]) + '-' + str(dataframe['Month'][i])
    dataframe.drop(['Year','Month'],axis = 1,inplace = True)
    order = ['Date','Energy','DC Capacity','Location']
    dataframe_new = dataframe[order]
    
    return(dataframe_new)

# %%
add_time_col(nortech)
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Date   Energy DC Capacity   Location
# 0   2014-11    20.22         6.6  Fairbanks
# 1   2014-12     2.83
# 2    2015-1    57.47
# 3    2015-2   215.92
# 4    2015-3   928.97
# 5    2015-4  1332.11
# 6    2015-5  1479.90
# 7    2015-6  1233.17
# 8    2015-7  1087.13
# 9    2015-8   777.93
# 10   2015-9   520.24
# 11  2015-10   416.43
# 12  2015-11    13.73
# 13  2015-12     8.03
# 14   2016-1    45.18
# 15   2016-2   374.27
# 16   2016-3   858.71
# 17   2016-4  1137.44
# 18   2016-5  1146.16
# 19   2016-6  1222.94
# 20   2016-7  1015.14
# 21   2016-8  1018.37
# 22   2016-9   603.98
# 23  2016-10   355.67
# 24  2016-11    69.65
# 25  2016-12     4.66
# 26   2017-1     5.66
# 27   2017-2   191.78
# 28   2017-3  1158.26
# 29   2017-4  1533.42
# 30   2017-5  1377.63
# 31   2017-6  1463.75
# 32   2017-7  1185.17
