# %%
import pandas as pd
import numpy as np
from the_needed_function import drop_the_hours
from the_needed_function import seperate_date

# %%
braun_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/braun/572156_system_energy_20150226_to_20190522.csv')
Dashevsky_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/Dashevsky/721120_system_energy_20150828_to_20190522 (1).csv')
davis_Wasilla = pd.read_csv('../Cleaned_data/ABS Alaskan/Davis/273944_system_energy_20131115_to_20190522.csv')
deer_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/Deer/1062205_system_energy_20160927_to_20190522.csv')
dukeminier_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/Dukeminier/716566_system_energy_20150824_to_20190522.csv')
fireweed_Anchorage = pd.read_csv('../Cleaned_data/ABS Alaskan/FireweedBusCenter/945883_system_energy_20160520_to_20190522.csv')
Tran_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/GenaTran/28253_system_energy_20110826_to_20190522.csv')
grubis_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/Grubis/660658_system_energy_20150705_to_20190522.csv')
hall_North_pole = pd.read_csv('../Cleaned_data/ABS Alaskan/Hall/1000407_system_energy_20160804_to_20190522.csv')
jorgenson_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/jorgenson/802562_system_energy_20151221_to_20190522.csv')
kogl_denali_park = pd.read_csv('../Cleaned_data/ABS Alaskan/Kogl/1030153_system_energy_20160929_to_20190522.csv')
ronlevy_Soldotna = pd.read_csv('../Cleaned_data/ABS Alaskan/RonLevy/29009_system_energy_20110831_to_20190522.csv')
albin_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/SolarFox/394826_system_energy_20140729_to_20190522.csv')
wiessman_fairbanks = pd.read_csv('../Cleaned_data/ABS Alaskan/Wiessman_Fairbanks/720232_system_energy_20150827_to_20190522.csv')

# %%
drop_the_hours(braun_fairbanks)
drop_the_hours(Dashevsky_fairbanks)
drop_the_hours(davis_Wasilla)
drop_the_hours(deer_fairbanks)
drop_the_hours(dukeminier_fairbanks)
drop_the_hours(fireweed_Anchorage)
drop_the_hours(Tran_fairbanks)
drop_the_hours(grubis_fairbanks)
drop_the_hours(hall_North_pole)
drop_the_hours(jorgenson_fairbanks)
drop_the_hours(kogl_denali_park)
drop_the_hours(ronlevy_Soldotna)
drop_the_hours(albin_fairbanks)
drop_the_hours(wiessman_fairbanks)
# Out:
#       Date/Time  Energy Produced (Wh)
# 0     8/27/2015                  2927
# 1     8/28/2015                  7106
# 2     8/29/2015                  6720
# 3     8/30/2015                 12858
# 4     8/31/2015                 11036
# 5      9/1/2015                 17431
# 6      9/2/2015                 19792
# 7      9/3/2015                 16644
# 8      9/4/2015                 16377
# 9      9/5/2015                 18488
# 10     9/6/2015                 20350
# 11     9/7/2015                 14510
# 12     9/8/2015                  8682
# 13     9/9/2015                  8949
# 14    9/10/2015                  8961
# 15    9/11/2015                 13280
# 16    9/12/2015                  4609
# 17    9/13/2015                  1953
# 18    9/14/2015                  3047
# 19    9/15/2015                  4078
# 20    9/16/2015                  3011
# 21    9/17/2015                  3016
# 22    9/18/2015                  3909
# 23    9/19/2015                  3541
# ...

# %%
braun_fairbanks_new = seperate_date(braun_fairbanks)
Dashevsky_fairbanks_new = seperate_date(Dashevsky_fairbanks)
davis_Wasilla_new = seperate_date(davis_Wasilla)
deer_fairbanks_new = seperate_date(deer_fairbanks)
dukeminier_fairbanks_new = seperate_date(dukeminier_fairbanks)
fireweed_Anchorage_new = seperate_date(fireweed_Anchorage)
Tran_fairbanks_new = seperate_date(Tran_fairbanks)
grubis_fairbanks_new = seperate_date(grubis_fairbanks)
hall_North_pole_new = seperate_date(hall_North_pole)
jorgenson_fairbanks_new = seperate_date(jorgenson_fairbanks)
kogl_denali_park_new = seperate_date(kogl_denali_park)
ronlevy_Soldotna_new = seperate_date(ronlevy_Soldotna)
albin_fairbanks_new = seperate_date(albin_fairbanks)
wiessman_fairbanks_new = seperate_date(wiessman_fairbanks)

# %%
braun_fairbanks_new['Interpolate']=0
braun_fairbanks_new['DC Capacity']= ""
braun_fairbanks_new['Location']= ""
braun_fairbanks_new['DC Capacity'][0]=3.75
braun_fairbanks_new['Location'][0]='Fairbanks'
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
braun_fairbanks_new.to_csv('braun_fairbanks_new',index=False)

# %%
Dashevsky_fairbanks_new['Interpolate']=0
Dashevsky_fairbanks_new['DC Capacity']= ""
Dashevsky_fairbanks_new['Location']= ""
Dashevsky_fairbanks_new['DC Capacity'][0]=3.06
Dashevsky_fairbanks_new['Location'][0]='Fairbanks'
Dashevsky_fairbanks_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2015      8   28   1.108            0        3.06  Fairbanks
# 1     2015      8   29   2.616            0
# 2     2015      8   30   5.588            0
# 3     2015      8   31   4.681            0
# 4     2015      9    1   8.323            0
# 5     2015      9    2   8.393            0
# ...

# %%
Dashevsky_fairbanks_new.to_csv('Dashevsky_fairbanks_new',index=False)

# %%
davis_Wasilla_new['Interpolate']=0
davis_Wasilla_new['DC Capacity']= ""
davis_Wasilla_new['Location']= ""
davis_Wasilla_new['DC Capacity'][0]=1.5
davis_Wasilla_new['Location'][0]='Wasilla'
davis_Wasilla_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0     2013     11   15   0.003            0         1.5  Wasilla
# 1     2013     11   16   0.034            0
# 2     2013     11   17   0.038            0
# 3     2013     11   18   0.044            0
# 4     2013     11   19   0.042            0
# 5     2013     11   20   0.042            0
# ...

# %%
davis_Wasilla_new.to_csv('davis_Wasilla_new',index=False)

# %%
deer_fairbanks_new['Interpolate']=0
deer_fairbanks_new['DC Capacity']= ""
deer_fairbanks_new['Location']= ""
deer_fairbanks_new['DC Capacity'][0]=3.5
deer_fairbanks_new['Location'][0]='Fairbanks'
deer_fairbanks_new.to_csv('deer_fairbanks_new',index=False)
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
dukeminier_fairbanks_new['Interpolate']=0
dukeminier_fairbanks_new['DC Capacity']= ""
dukeminier_fairbanks_new['Location']= ""
dukeminier_fairbanks_new['DC Capacity'][0]=4.08
dukeminier_fairbanks_new['Location'][0]='Fairbanks'
dukeminier_fairbanks_new.to_csv('dukeminier_fairbanks_new',index=False)
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
fireweed_Anchorage_new['Interpolate']=0
fireweed_Anchorage_new['DC Capacity']= ""
fireweed_Anchorage_new['Location']= ""
fireweed_Anchorage_new['DC Capacity'][0]=11.9
fireweed_Anchorage_new['Location'][0]='Anchorage'
fireweed_Anchorage_new.to_csv('fireweed_Anchorage_new',index=False)
fireweed_Anchorage_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2016      5   20   0.000            0        11.9  Anchorage
# 1     2016      5   21   0.000            0
# 2     2016      5   22   0.000            0
# 3     2016      5   23   0.000            0
# 4     2016      5   24   0.000            0
# 5     2016      5   25   0.000            0
# ...

# %%
Tran_fairbanks_new['Interpolate']=0
Tran_fairbanks_new['DC Capacity']= ""
Tran_fairbanks_new['Location']= ""
Tran_fairbanks_new['DC Capacity'][0]=1.9
Tran_fairbanks_new['Location'][0]='Fairbanks'
Tran_fairbanks_new.to_csv('Tran_fairbanks_new',index=False)
Tran_fairbanks_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2011      8   26   6.584            0         1.9  Fairbanks
# 1     2011      8   27   8.018            0
# 2     2011      8   28   8.348            0
# 3     2011      8   29   7.610            0
# 4     2011      8   30   6.364            0
# 5     2011      8   31   4.081            0
# ...

# %%
grubis_fairbanks_new['Interpolate']=0
grubis_fairbanks_new['DC Capacity']= ""
grubis_fairbanks_new['Location']= ""
grubis_fairbanks_new['DC Capacity'][0]=3.12
grubis_fairbanks_new['Location'][0]='Fairbanks'
grubis_fairbanks_new.to_csv('grubis_fairbanks_new',index=False)
grubis_fairbanks_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2015      7    5   0.010            0        3.12  Fairbanks
# 1     2015      7    6   6.139            0
# 2     2015      7    7   3.790            0
# 3     2015      7    8  12.401            0
# 4     2015      7    9   7.834            0
# 5     2015      7   10  20.255            0
# ...

# %%
hall_North_pole_new['Interpolate']=0
hall_North_pole_new['DC Capacity']= ""
hall_North_pole_new['Location']= ""
hall_North_pole_new['DC Capacity'][0]=3.83
hall_North_pole_new['Location'][0]='North Pole'
hall_North_pole_new.to_csv('hall_North_pole_new',index=False)
hall_North_pole_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity    Location
# 0     2016      8    4   0.000            0        3.83  North Pole
# 1     2016      8    5   0.000            0
# 2     2016      8    6   0.000            0
# 3     2016      8    7   0.000            0
# 4     2016      8    8  13.765            0
# 5     2016      8    9   7.877            0
# ...

# %%
jorgenson_fairbanks_new['Interpolate']=0
jorgenson_fairbanks_new['DC Capacity']= ""
jorgenson_fairbanks_new['Location']= ""
jorgenson_fairbanks_new['DC Capacity'][0]=3.06
jorgenson_fairbanks_new['Location'][0]='Fairbanks'
jorgenson_fairbanks_new.to_csv('jorgenson_fairbanks_new',index=False)
jorgenson_fairbanks_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2015     12   21   0.064            0        3.06  Fairbanks
# 1     2015     12   22   0.917            0
# 2     2015     12   23   1.912            0
# 3     2015     12   24   2.577            0
# 4     2015     12   25   3.347            0
# 5     2015     12   26   4.066            0
# ...

# %%
kogl_denali_park_new['Interpolate']=0
kogl_denali_park_new['DC Capacity']= ""
kogl_denali_park_new['Location']= ""
kogl_denali_park_new['DC Capacity'][0]=4
kogl_denali_park_new['Location'][0]='Denali park'
kogl_denali_park_new.to_csv('kogl_denali_park_new',index=False)
kogl_denali_park_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity     Location
# 0    2016      9   29   6.088            0           4  Denali park
# 1    2016      9   30  13.221            0
# 2    2016     10    1  11.792            0
# 3    2016     10    2   2.687            0
# 4    2016     10    3   1.996            0
# 5    2016     10    4   2.464            0
# ...

# %%
ronlevy_Soldotna_new['Interpolate']=0
ronlevy_Soldotna_new['DC Capacity']= ""
ronlevy_Soldotna_new['Location']= ""
ronlevy_Soldotna_new['DC Capacity'][0]=7.6
ronlevy_Soldotna_new['Location'][0]='Soldotna'
ronlevy_Soldotna_new.to_csv('ronlevy_Soldotna_new',index=False)
ronlevy_Soldotna_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity  Location
# 0     2011      8   31   0.003            0         7.6  Soldotna
# 1     2011      9    1  31.842            0
# 2     2011      9    2  12.791            0
# 3     2011      9    3  18.911            0
# 4     2011      9    4  12.243            0
# 5     2011      9    5  11.956            0
# ...

# %%
albin_fairbanks_new['Interpolate']=0
albin_fairbanks_new['DC Capacity']= ""
albin_fairbanks_new['Location']= ""
albin_fairbanks_new['DC Capacity'][0]=4
albin_fairbanks_new['Location'][0]='Fairbanks'
albin_fairbanks_new.to_csv('albin_fairbanks_new',index=False)
albin_fairbanks_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2014      7   29  18.996            0           4  Fairbanks
# 1     2014      7   30  18.455            0
# 2     2014      7   31  11.325            0
# 3     2014      8    1   1.626            0
# 4     2014      8    2   1.560            0
# 5     2014      8    3  12.551            0
# ...

# %%
wiessman_fairbanks_new['Interpolate']=0
wiessman_fairbanks_new['DC Capacity']= ""
wiessman_fairbanks_new['Location']= ""
wiessman_fairbanks_new['DC Capacity'][0]=3.1
wiessman_fairbanks_new['Location'][0]='Fairbanks'
wiessman_fairbanks_new.to_csv('wiessman_fairbanks_new',index=False)
wiessman_fairbanks_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0     2015      8   27   2.927            0         3.1  Fairbanks
# 1     2015      8   28   7.106            0
# 2     2015      8   29   6.720            0
# 3     2015      8   30  12.858            0
# 4     2015      8   31  11.036            0
# 5     2015      9    1  17.431            0
# ...
