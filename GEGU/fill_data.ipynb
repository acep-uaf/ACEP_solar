# %% [markdown]
# ## This is a notebook that use the function to fill all the files with missin data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from the_needed_function import filled_missingdata_with_ML
from the_needed_function import filling_missing_data

# %%
bethel = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Bethel_cleaned.xlsx')

bethel_complete = filled_missingdata_with_ML(bethel)

plt.plot(bethel_complete['Energy'])
#plt.plot(bethel['Energy'])
# Out:
# /Users/guge/Desktop/acep-solar/new/ACEP_solar/GEGU/the_needed_function.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe_with_predicted['Status'][i] = 0

# %%
bethel_complete.to_csv('bethel_complete',index=False)

# %%
deering = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Deering_cleaned.xlsx')

deering_complete = filled_missingdata_with_ML(deering)

plt.plot(deering_complete['Energy'])
plt.plot(deering['Energy'])
# Out:
# /Users/guge/Desktop/acep-solar/new/ACEP_solar/GEGU/the_needed_function.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe_with_predicted['Status'][i] = 0

# %%
deering_complete.to_csv('deering_complete',index=False)

# %%
galena = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Galena_cleaned.xlsx')

galena_complete = filled_missingdata_with_ML(galena)

plt.plot(galena_complete['Energy'])
plt.plot(galena['Energy'])
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
kobuk = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Kobuk_cleaned.xlsx')

kobuk_complete = filled_missingdata_with_ML(kobuk)

plt.plot(kobuk_complete['Energy'])
plt.plot(kobuk['Energy'])
# Out:
# /Users/guge/Desktop/acep-solar/new/ACEP_solar/GEGU/the_needed_function.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe_with_predicted['Status'][i] = 0

# %%
nootak = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Nootak_cleaned.xlsx')

nootak_complete = filled_missingdata_with_ML(nootak)

plt.plot(nootak_complete['Energy'])
plt.plot(nootak['Energy'])
# Out:
# /Users/guge/Desktop/acep-solar/new/ACEP_solar/GEGU/the_needed_function.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe_with_predicted['Status'][i] = 0

# %%
nootak_complete['Energy'][13]=0
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(len(nootak_complete)):
    if nootak_complete['Energy'][i] < 0:
        nootak_complete['Energy'][i] = 0
    else:
        pass
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(nootak_complete['Energy'])
plt.plot(nootak['Energy'])

# %%
nootak_complete.to_csv('nootak_complete',index=False)

# %%
norvilk = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Norvik_cleaned.xlsx')

norvilk_complete = filled_missingdata_with_ML(norvilk)

plt.plot(norvilk_complete['Energy'])
plt.plot(norvilk['Energy'])
# Out:
# /Users/guge/Desktop/acep-solar/new/ACEP_solar/GEGU/the_needed_function.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe_with_predicted['Status'][i] = 0

# %%
norvilk_complete.to_csv('norvilk_complete',index=False)

# %%
shungnak = pd.read_excel('../Cleaned_data/RuralAk/RuralAK_Shungnak_cleaned.xlsx')

shungnak_complete = filled_missingdata_with_ML(shungnak)

plt.plot(shungnak_complete['Energy'])
plt.plot(shungnak['Energy'])
# Out:
# /Users/guge/Desktop/acep-solar/new/ACEP_solar/GEGU/the_needed_function.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe_with_predicted['Status'][i] = 0

# %%
for i in range(len(shungnak_complete)):
    if shungnak_complete['Energy'][i] < 0:
        shungnak_complete['Energy'][i] = 0
    else:
        pass
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(shungnak_complete['Energy'])
plt.plot(shungnak['Energy'])

# %%
shungnak_complete.to_csv('shungnak_complete',index=False)
