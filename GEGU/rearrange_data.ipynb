# %%
import pandas as pd
import numpy as np
from the_needed_function import drop_the_hours
from the_needed_function import seperate_date

# %%
breeze_Anchorage = pd.read_csv('../Cleaned_data/data/309Breeze.csv')
huffman_Anchorage = pd.read_csv('../Cleaned_data/data/12800Huffman.csv')
tahneeta_Anchorage = pd.read_csv('../Cleaned_data/data/10611Tahneeta.csv')
wildwood_Anchorage = pd.read_csv('../Cleaned_data/data/1957Wildwood.csv')
alumni_Anchorage = pd.read_csv('../Cleaned_data/data/3800Alumni.csv')

tedrow_Eagle_river = pd.read_csv('../Cleaned_data/data/18306Tedrow.csv')

trailways_Chickaloon = pd.read_csv('../Cleaned_data/data/34738Trailways.csv')

glennhill_Chugiak = pd.read_csv('../Cleaned_data/data/23221GlennHill.csv')

westlake_palmer = pd.read_csv('../Cleaned_data/data/3700Westlake.csv')
biscane_palmer = pd.read_csv('../Cleaned_data/data/1232Biscane.csv')
mckeen_palmer = pd.read_csv('../Cleaned_data/data/4700McKeen.csv')
farmloop_palmer = pd.read_csv('../Cleaned_data/data/4700FarmLoop.csv')
alask_palmer = pd.read_csv('../Cleaned_data/data/550S_Alaska.csv')
fishhood_palmer = pd.read_csv('../Cleaned_data/data/5200N_PalmerFishhook.csv')

redfox_wasilla = pd.read_csv('../Cleaned_data/data/2150E_RedFox.csv')
countryfield_wasilla = pd.read_csv('../Cleaned_data/data/4048E_CountryFieldCircle.csv')
reliance_wasilla = pd.read_csv('../Cleaned_data/data/5007Reliance.csv')

woodside_homer = pd.read_csv('../Cleaned_data/data/326Woodside.csv')

# %%
def drop_the_hours (dataframe):
    """This function is to drop the hours in the first columns of the daily data
    
       Arg:
       dataframe(string):The name of the dataframe that you want to change
       
       Return:
       the dataframe after changed
    """
    
    date_time = []
    
    for i in range(len(dataframe)):
        date_time.append(dataframe['Date/Time'][i].rsplit(' ',2)[0])
    
    dataframe['Date/Time']=date_time
    dataframe.drop(dataframe.tail(1).index,inplace=True)
    
    return(dataframe)

def seperate_date(dataframe):
    """This function will create a new dataframe that contains the columns in order of 'Year','Month','Day','Energy'
    
       Args:
       dataframe（string):The name of the dataframe contain the data you want to use
       
       Return:
       A new dataframe
    """
    
    dataframe_new = pd.DataFrame(columns=['Year','Month','Day','Energy'])
    year=[]
    month=[]
    day=[]
    energy=[]
    
    for i in range(len(dataframe)):
        year.append(int(dataframe['Date/Time'][i].rsplit('-',2)[0]))
        month.append(int(dataframe['Date/Time'][i].rsplit('-',2)[1]))
        day.append(int(dataframe['Date/Time'][i].rsplit('-',2)[2]))
        energy.append(dataframe['Energy Produced (Wh)'][i]/1000)
    
    dataframe_new['Year']=year
    dataframe_new['Month']=month
    dataframe_new['Day']=day
    dataframe_new['Energy'] = energy
    
    return(dataframe_new)

# %%
drop_the_hours(breeze_Anchorage)
drop_the_hours(huffman_Anchorage)
drop_the_hours(tahneeta_Anchorage)
drop_the_hours(wildwood_Anchorage)
drop_the_hours(alumni_Anchorage)
# Out:
#       Date/Time  Energy Produced (Wh)
# 0    2018-02-21                   687
# 1    2018-02-22                  3993
# 2    2018-02-23                 12196
# 3    2018-02-24                  6938
# 4    2018-02-25                 11990
# 5    2018-02-26                  1320
# 6    2018-02-27                 13090
# 7    2018-02-28                 16523
# 8    2018-03-01                 15651
# 9    2018-03-02                  2936
# 10   2018-03-03                  1788
# 11   2018-03-04                  4259
# 12   2018-03-05                  5425
# 13   2018-03-06                  2353
# 14   2018-03-07                  8859
# 15   2018-03-08                  1320
# 16   2018-03-09                  3731
# 17   2018-03-10                 10126
# 18   2018-03-11                  2656
# 19   2018-03-12                 11139
# 20   2018-03-13                 10171
# 21   2018-03-14                  4205
# 22   2018-03-15                  7131
# 23   2018-03-16                  1921
# ...

# %%
breeze_Anchorage_new = seperate_date(breeze_Anchorage)
huffman_Anchorage_new = seperate_date(huffman_Anchorage)
tahneeta_Anchorage_new = seperate_date(tahneeta_Anchorage)
wildwood_Anchorage_new = seperate_date(wildwood_Anchorage)
alumni_Anchorage_new = seperate_date(alumni_Anchorage)

# %%
breeze_Anchorage_new['Interpolate']=0
breeze_Anchorage_new['DC Capacity']= ""
breeze_Anchorage_new['Location']= ""
breeze_Anchorage_new['DC Capacity'][0]=2.9
breeze_Anchorage_new['Location'][0]='Anchorage'
breeze_Anchorage_new.to_csv('breeze_Anchorage_new',index=False)
breeze_Anchorage_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0    2017      2    5   0.037            0         2.9  Anchorage
# 1    2017      2    6   0.119            0
# 2    2017      2    7   0.141            0
# 3    2017      2    8   0.223            0
# 4    2017      2    9   0.038            0
# 5    2017      2   10   0.053            0
# ...

# %%
huffman_Anchorage_new['Interpolate']=0
huffman_Anchorage_new['DC Capacity']= ""
huffman_Anchorage_new['Location']= ""
huffman_Anchorage_new['DC Capacity'][0]=3.6
huffman_Anchorage_new['Location'][0]='Anchorage'
huffman_Anchorage_new.to_csv('huffman_Anchorage_new',index=False)
huffman_Anchorage_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0    2017      5   31  11.641            0         3.6  Anchorage
# 1    2017      6    1  24.026            0
# 2    2017      6    2  23.821            0
# 3    2017      6    3  21.138            0
# 4    2017      6    4   8.250            0
# 5    2017      6    5  11.954            0
# ...

# %%
tahneeta_Anchorage_new['Interpolate']=0
tahneeta_Anchorage_new['DC Capacity']= ""
tahneeta_Anchorage_new['Location']= ""
tahneeta_Anchorage_new['DC Capacity'][0]=3
tahneeta_Anchorage_new['Location'][0]='Anchorage'
tahneeta_Anchorage_new.to_csv('tahneeta_Anchorage_new',index=False)
tahneeta_Anchorage_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0    2017      6    2  11.130            0           3  Anchorage
# 1    2017      6    3  19.115            0
# 2    2017      6    4   5.566            0
# 3    2017      6    5  13.087            0
# 4    2017      6    6   7.775            0
# 5    2017      6    7   7.973            0
# ...

# %%
wildwood_Anchorage_new['Interpolate']=0
wildwood_Anchorage_new['DC Capacity']= ""
wildwood_Anchorage_new['Location']= ""
wildwood_Anchorage_new['DC Capacity'][0]=5.1
wildwood_Anchorage_new['Location'][0]='Anchorage'
wildwood_Anchorage_new.to_csv('wildwood_Anchorage_new',index=False)
wildwood_Anchorage_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0    2017      6    7   9.874            0         5.1  Anchorage
# 1    2017      6    8  16.312            0
# 2    2017      6    9  18.373            0
# 3    2017      6   10   5.251            0
# 4    2017      6   11  20.687            0
# 5    2017      6   12  13.428            0
# ...

# %%
alumni_Anchorage_new['Interpolate']=0
alumni_Anchorage_new['DC Capacity']= ""
alumni_Anchorage_new['Location']= ""
alumni_Anchorage_new['DC Capacity'][0]=2.6
alumni_Anchorage_new['Location'][0]='Anchorage'
alumni_Anchorage_new.to_csv('alumni_Anchorage_new',index=False)
alumni_Anchorage_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity   Location
# 0    2018      2   21   0.687            0         2.6  Anchorage
# 1    2018      2   22   3.993            0
# 2    2018      2   23  12.196            0
# 3    2018      2   24   6.938            0
# 4    2018      2   25  11.990            0
# 5    2018      2   26   1.320            0
# ...

# %%
drop_the_hours(tedrow_Eagle_river)
drop_the_hours(trailways_Chickaloon)
drop_the_hours(glennhill_Chugiak)

tedrow_Eagle_river_new = seperate_date(tedrow_Eagle_river)
trailways_Chickaloon_new = seperate_date(trailways_Chickaloon)
glennhill_Chugiak_new = seperate_date(glennhill_Chugiak)

# %%
tedrow_Eagle_river_new['Interpolate']=0
tedrow_Eagle_river_new['DC Capacity']= ""
tedrow_Eagle_river_new['Location']= ""
tedrow_Eagle_river_new['DC Capacity'][0]=6
tedrow_Eagle_river_new['Location'][0]='Eagle River'
tedrow_Eagle_river_new.to_csv('tedrow_Eagle_river_new',index=False)
tedrow_Eagle_river_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity     Location
# 0    2017      8    7   2.154            0           6  Eagle River
# 1    2017      8    8  22.420            0
# 2    2017      8    9   9.000            0
# 3    2017      8   10  13.450            0
# 4    2017      8   11  10.060            0
# 5    2017      8   12   8.297            0
# ...

# %%
trailways_Chickaloon_new['Interpolate']=0
trailways_Chickaloon_new['DC Capacity']= ""
trailways_Chickaloon_new['Location']= ""
trailways_Chickaloon_new['DC Capacity'][0]=3.2
trailways_Chickaloon_new['Location'][0]='Chickaloon'
trailways_Chickaloon_new.to_csv('trailways_Chickaloon_new',index=False)
trailways_Chickaloon_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity    Location
# 0    2017      8   25   2.444            0         3.2  Chickaloon
# 1    2017      8   26   7.929            0
# 2    2017      8   27   8.867            0
# 3    2017      8   28  12.867            0
# 4    2017      8   29   4.145            0
# 5    2017      8   30   5.118            0
# ...

# %%
glennhill_Chugiak_new['Interpolate']=0
glennhill_Chugiak_new['DC Capacity']= ""
glennhill_Chugiak_new['Location']= ""
glennhill_Chugiak_new['DC Capacity'][0]=2.5
glennhill_Chugiak_new['Location'][0]='Chugiak'
glennhill_Chugiak_new.to_csv('glennhill_Chugiak_new',index=False)
glennhill_Chugiak_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2017      9   29   2.550            0         2.5  Chugiak
# 1    2017      9   30   9.924            0
# 2    2017     10    1   6.391            0
# 3    2017     10    2   3.254            0
# 4    2017     10    3   3.822            0
# 5    2017     10    4   2.074            0
# ...

# %%
drop_the_hours(westlake_palmer)
drop_the_hours(biscane_palmer)
drop_the_hours(mckeen_palmer)
drop_the_hours(farmloop_palmer)
drop_the_hours(alask_palmer)
drop_the_hours(fishhood_palmer)

westlake_palmer_new = seperate_date(westlake_palmer)
biscane_palmer_new = seperate_date(biscane_palmer)
mckeen_palmer_new = seperate_date(mckeen_palmer)
farmloop_palmer_new = seperate_date(farmloop_palmer)
alask_palmer_new = seperate_date(alask_palmer)
fishhood_palmer_new = seperate_date(fishhood_palmer)

# %%
westlake_palmer_new['Interpolate']=0
westlake_palmer_new['DC Capacity']= ""
westlake_palmer_new['Location']= ""
westlake_palmer_new['DC Capacity'][0]=5.1
westlake_palmer_new['Location'][0]='Palmer'
westlake_palmer_new.to_csv('westlake_palmer_new',index=False)
westlake_palmer_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2017     10   11   2.994            0         5.1   Palmer
# 1    2017     10   12   1.421            0
# 2    2017     10   13   4.723            0
# 3    2017     10   14   6.779            0
# 4    2017     10   15   9.683            0
# 5    2017     10   16  11.072            0
# ...

# %%
biscane_palmer_new['Interpolate']=0
biscane_palmer_new['DC Capacity']= ""
biscane_palmer_new['Location']= ""
biscane_palmer_new['DC Capacity'][0]=4.2
biscane_palmer_new['Location'][0]='Palmer'
biscane_palmer_new.to_csv('biscane_palmer_new',index=False)
biscane_palmer_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2017     10   11   2.469            0         4.2   Palmer
# 1    2017     10   12   1.304            0
# 2    2017     10   13   5.913            0
# 3    2017     10   14   6.983            0
# 4    2017     10   15  10.617            0
# 5    2017     10   16  12.538            0
# ...

# %%
mckeen_palmer_new['Interpolate']=0
mckeen_palmer_new['DC Capacity']= ""
mckeen_palmer_new['Location']= ""
mckeen_palmer_new['DC Capacity'][0]=6.6
mckeen_palmer_new['Location'][0]='Palmer'
mckeen_palmer_new.to_csv('mckeen_palmer_new',index=False)
mckeen_palmer_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2017     10   12   8.801            0         6.6   Palmer
# 1    2017     10   13   4.604            0
# 2    2017     10   14   7.374            0
# 3    2017     10   15   7.670            0
# 4    2017     10   16   7.497            0
# 5    2017     10   17   4.783            0
# ...

# %%
farmloop_palmer_new['Interpolate']=0
farmloop_palmer_new['DC Capacity']= ""
farmloop_palmer_new['Location']= ""
farmloop_palmer_new['DC Capacity'][0]=3.6
farmloop_palmer_new['Location'][0]='Palmer'
farmloop_palmer_new.to_csv('farmloop_palmer_new',index=False)
farmloop_palmer_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2017     11    9   0.041            0         3.6   Palmer
# 1    2017     11   10   0.350            0
# 2    2017     11   11   1.409            0
# 3    2017     11   12   1.043            0
# 4    2017     11   13   1.383            0
# 5    2017     11   14   1.824            0
# ...

# %%
alask_palmer_new['Interpolate']=0
alask_palmer_new['DC Capacity']= ""
alask_palmer_new['Location']= ""
alask_palmer_new['DC Capacity'][0]=14.4
alask_palmer_new['Location'][0]='Palmer'
alask_palmer_new.to_csv('alask_palmer_new',index=False)
alask_palmer_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2018      1   24   0.586            0        14.4   Palmer
# 1    2018      1   25   0.000            0
# 2    2018      1   26   0.031            0
# 3    2018      1   27   0.193            0
# 4    2018      1   28   0.280            0
# 5    2018      1   29  13.032            0
# ...

# %%
fishhood_palmer_new['Interpolate']=0
fishhood_palmer_new['DC Capacity']= ""
fishhood_palmer_new['Location']= ""
fishhood_palmer_new['DC Capacity'][0]=9.1
fishhood_palmer_new['Location'][0]='Palmer'
fishhood_palmer_new.to_csv('fishhood_palmer_new',index=False)
fishhood_palmer_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2018      4   19  45.751            0         9.1   Palmer
# 1    2018      4   20  40.555            0
# 2    2018      4   21  40.325            0
# 3    2018      4   22  39.560            0
# 4    2018      4   23  31.013            0
# 5    2018      4   24   6.259            0
# ...

# %%
drop_the_hours(redfox_wasilla)
drop_the_hours(countryfield_wasilla)
drop_the_hours(reliance_wasilla)

redfox_wasilla_new = seperate_date(redfox_wasilla)
countryfield_wasilla_new = seperate_date(countryfield_wasilla)
reliance_wasilla_new = seperate_date(reliance_wasilla)

# %%
redfox_wasilla_new['Interpolate']=0
redfox_wasilla_new['DC Capacity']= ""
redfox_wasilla_new['Location']= ""
redfox_wasilla_new['DC Capacity'][0]=3.6
redfox_wasilla_new['Location'][0]='Wasilla'
redfox_wasilla_new.to_csv('redfox_wasilla_new',index=False)
redfox_wasilla_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2017     10   12   3.494            0         3.6  Wasilla
# 1    2017     10   13   2.497            0
# 2    2017     10   14   3.952            0
# 3    2017     10   15   3.300            0
# 4    2017     10   16   3.585            0
# 5    2017     10   17   3.195            0
# ...

# %%
countryfield_wasilla_new['Interpolate']=0
countryfield_wasilla_new['DC Capacity']= ""
countryfield_wasilla_new['Location']= ""
countryfield_wasilla_new['DC Capacity'][0]=3.6
countryfield_wasilla_new['Location'][0]='Wasilla'
countryfield_wasilla_new.to_csv('countryfield_wasilla_new',index=False)
countryfield_wasilla_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2018      1    8   0.000            0         3.6  Wasilla
# 1    2018      1    9   0.302            0
# 2    2018      1   10   0.120            0
# 3    2018      1   11   0.097            0
# 4    2018      1   12   0.285            0
# 5    2018      1   13   0.085            0
# ...

# %%
reliance_wasilla_new['Interpolate']=0
reliance_wasilla_new['DC Capacity']= ""
reliance_wasilla_new['Location']= ""
reliance_wasilla_new['DC Capacity'][0]=6
reliance_wasilla_new['Location'][0]='Wasilla'
reliance_wasilla_new.to_csv('reliance_wasilla_new',index=False)
reliance_wasilla_new
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Year  Month  Day  Energy  Interpolate DC Capacity Location
# 0    2018      3   29   1.443            0           6  Wasilla
# 1    2018      3   30   2.801            0
# 2    2018      3   31  11.175            0
# 3    2018      4    1  17.139            0
# 4    2018      4    2  23.384            0
# 5    2018      4    3  25.131            0
# ...

# %%
drop_the_hours(woodside_homer)
woodside_homer_new = seperate_date(woodside_homer)

# %%
woodside_homer_new['Interpolate']=0
woodside_homer_new['DC Capacity']= ""
woodside_homer_new['Location']= ""
woodside_homer_new['DC Capacity'][0]=6
woodside_homer_new['Location'][0]='Wasilla'
woodside_homer_new.to_csv('reliance_wasilla_new',index=False)
woodside_homer_new
