# %%
import os
import folium
import pandas as pd
import branca

# %%
alaska= folium.Map(location = [63.977161, -152.024667], zoom_start = 4)
alaska
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Anchorage
folium.Marker([61.193625, -149.694974], popup = 'Anchorage, AK.', 
              tooltip = 'Anchorage, AK.').add_to(alaska)
#Kodiak
folium.Marker([57.794934, -152.392466], popup = 'Kodiak, AK.', 
              tooltip = 'Kodiak, AK.').add_to(alaska)
#Nome
folium.Marker([64.516804, -165.399455], popup = 'Nome, AK.', 
              tooltip = 'Nome, AK.').add_to(alaska)
#Juneau
folium.Marker([58.306096, -134.422802], popup = 'Juneau, AK.', 
              tooltip = 'Juneau, AK.').add_to(alaska)
#Prudhoe Bay
folium.Marker([70.212820, -148.408886], popup = 'Prudhoe Bay, AK.', 
              tooltip = 'Prudhoe Bay, AK.').add_to(alaska)
#Kotzebue
folium.Marker([66.888948, -162.512280], popup = 'Kotzebue, AK.',
              tooltip = 'Kotzebue, AK.').add_to(alaska)
#Bethel
folium.Marker([60.794938, -161.770716], popup = 'Bethel, AK.', 
              tooltip = 'Bethel, AK.').add_to(alaska)

# %%
#Homepage

#Fairbanks


html = """
    <h1> The Solar Production of Fairbanks</h1><br>
   <head>
    
      <meta charset="utf-8">
      <title>Bokeh Plot</title>
      
      
        
          
        <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-1.2.0.min.css" type="text/css" />
        
        
          
        <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.2.0.min.js"></script>
        <script type="text/javascript">
            Bokeh.set_log_level("info");
        </script>
        
      
      
    
  </head>
  
  
  <body>
    
      
        
          
          
            
              <div class="bk-root" id="b037a5fb-ee18-48f1-81e3-2f79507799a1" data-root-id="1075"></div>
            
          
        
      
      
        <script type="application/json" id="1232">
          {"47cf5d5b-9fef-4778-8235-5876b92ad811":{"roots":{"references":[{"attributes":{},"id":"1128","type":"BasicTickFormatter"},{"attributes":{},"id":"1100","type":"ResetTool"},{"attributes":{"source":{"id":"1109","type":"ColumnDataSource"}},"id":"1113","type":"CDSView"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1129","type":"BoxAnnotation"},{"attributes":{"text":"Fairbanks errorbars"},"id":"1076","type":"Title"},{"attributes":{},"id":"1101","type":"HelpTool"},{"attributes":{},"id":"1130","type":"Selection"},{"attributes":{"callback":null},"id":"1078","type":"DataRange1d"},{"attributes":{},"id":"1131","type":"UnionRenderers"},{"attributes":{"callback":null},"id":"1080","type":"DataRange1d"},{"attributes":{"data_source":{"id":"1109","type":"ColumnDataSource"},"glyph":{"id":"1110","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1111","type":"Circle"},"selection_glyph":null,"view":{"id":"1113","type":"CDSView"}},"id":"1112","type":"GlyphRenderer"},{"attributes":{},"id":"1132","type":"Selection"},{"attributes":{"callback":null,"data":{"top":{"__ndarray__":"...","dtype":"float64","shape":[103]},"x":{"__ndarray__":"...","dtype":"float64","shape":[50]}},"selected":{"id":"1132","type":"Selection"},"selection_policy":{"id":"1133","type":"UnionRenderers"}},"id":"1114","type":"Col
{},"id":"1126","type":"BasicTickFormatter"},{"attributes":{"callback":null,"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[103]}},"selected":{"id":"1130","type":"Selection"},"selection_policy":{"id":"1131","type":"UnionRenderers"}},"id":"1109","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"1129","type":"BoxAnnotation"}},"id":"1098","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"1086","type":"LinearAxis"}],"center":[{"id":"1090","type":"Grid"},{"id":"1095","type":"Grid"}],"left":[{"id":"1091","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"1112","type":"GlyphRenderer"},{"id":"1117","type":"GlyphRenderer"},{"id":"1122","type":"GlyphRenderer"}],"title":{"id":"1076","type":"Title"},"toolbar":{"id":"1102","type":"Toolbar"},"x_range":{"id":"1078","type":"DataRange1d"},"x_scale":{"id":"1082","type":"LinearScale"},"y_range":{"id":"1080","type":"DataRange1d"},"y_scale":{"id":"1084","type":"LinearScale"}},"id":"1075","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1099","type":"SaveTool"}],"root_ids":["1075"]},"title":"Bokeh Application","version":"1.2.0"}}
        </script>
        <script type="text/javascript">
          (function() {
            var fn = function() {
              Bokeh.safely(function() {
                (function(root) {
                  function embed_document(root) {
                    
                  var docs_json = document.getElementById('1232').textContent;
                  var render_items = [{"docid":"47cf5d5b-9fef-4778-8235-5876b92ad811","roots":{"1075":"b037a5fb-ee18-48f1-81e3-2f79507799a1"}}];
                  root.Bokeh.embed.embed_items(docs_json, render_items);
                
                  }
                  if (root.Bokeh !== undefined) {
                    embed_document(root);
                  } else {
                    var attempts = 0;
                    var timer = setInterval(function(root) {
                      if (root.Bokeh !== undefined) {
                        embed_document(root);
                        clearInterval(timer);
                      }
                      attempts++;
                      if (attempts > 100) {
                        console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
                        clearInterval(timer);
                      }
                    }, 10, root)
                  }
                })(window);
              });
            };
            if (document.readyState != "loading") fn();
            else document.addEventListener("DOMContentLoaded", fn);
          })();
        </script>
    
  </body>

    </p>
    <a href="https://acep-solar.github.io/ACEP_solar/webpages/fairbanks" title="Go ahead" target="_blank" name="girl">Click Here for More Infromation</a>
   


    """

iframe = branca.element.IFrame(html=html, width=850, height=550)
popup = folium.Popup(iframe, max_width=850)

folium.Marker([64.838033, -147.668970], popup=popup,
              tooltip='Fairbanks, AK.').add_to(alaska)

alaska.save(os.path.join( 'index.html'))

alaska
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
<!DOCTYPE html>
<html>
<head>
<meta charset="utf-8">
<title>ACEP</title>
</head>
<body>
<p>
<img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Logo_TV_2015.svg/800px-Logo_TV_2015.svg.png" 
alt="Logo" style="float:right" width="120" height="120"> 
</p>
<h1>ACEP Solar</h1>

<p>This project objective is to calculate a number of different parameters and metrics for solar panels distributed throughout the state of Alaska, and generate an interactive graphic that enables users to investigate the costs and benefits to solar in their area, as well as provide a means to investigate if their panels are underperforming expected performance.</p>
	
<p>Please click the map and explore.</p>
	
	




	
	
	
	
	
	
	
	
</body>
</html>
